# %% [markdown]
# <h1>1 银行客户流失预测<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#项目任务" data-toc-modified-id="项目任务-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>项目任务</a></span></li><li><span><a href="#业务理解" data-toc-modified-id="业务理解-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>业务理解</a></span></li><li><span><a href="#数据理解" data-toc-modified-id="数据理解-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>数据理解</a></span><ul class="toc-item"><li><span><a href="#导入合适的包" data-toc-modified-id="导入合适的包-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>导入合适的包</a></span></li><li><span><a href="#获取数据" data-toc-modified-id="获取数据-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>获取数据</a></span></li><li><span><a href="#数据描述" data-toc-modified-id="数据描述-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>数据描述</a></span></li><li><span><a href="#缺失值分析" data-toc-modified-id="缺失值分析-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>缺失值分析</a></span></li></ul></li><li><span><a href="#数据准备" data-toc-modified-id="数据准备-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>数据准备</a></span><ul class="toc-item"><li><span><a href="#特征工程" data-toc-modified-id="特征工程-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>特征工程</a></span></li><li><span><a href="#数据集成与整理" data-toc-modified-id="数据集成与整理-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>数据集成与整理</a></span></li></ul></li><li><span><a href="#建模" data-toc-modified-id="建模-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>建模</a></span><ul class="toc-item"><li><span><a href="#搭建环境" data-toc-modified-id="搭建环境-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>搭建环境</a></span></li><li><span><a href="#比较模型" data-toc-modified-id="比较模型-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>比较模型</a></span></li><li><span><a href="#创建模型" data-toc-modified-id="创建模型-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>创建模型</a></span><ul class="toc-item"><li><span><a href="#调优模型" data-toc-modified-id="调优模型-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>调优模型</a></span></li></ul></li></ul></li><li><span><a href="#评价" data-toc-modified-id="评价-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>评价</a></span><ul class="toc-item"><li><span><a href="#评估模型" data-toc-modified-id="评估模型-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>评估模型</a></span></li><li><span><a href="#测试模型" data-toc-modified-id="测试模型-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>测试模型</a></span></li><li><span><a href="#部署模型" data-toc-modified-id="部署模型-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>部署模型</a></span></li><li><span><a href="#模型预测" data-toc-modified-id="模型预测-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>模型预测</a></span></li><li><span><a href="#保存实验" data-toc-modified-id="保存实验-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>保存实验</a></span></li></ul></li><li><span><a href="#结论" data-toc-modified-id="结论-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>结论</a></span></li></ul></div>

# %% [markdown]
# # 项目任务

# %% [markdown]
# 银行客户流失是指银行的客户终止在该行的所有业务，并销号。但在实际运营中，对于具体业务部门，银行客户流失可以定位为特定的业务终止行为。
#
# 商业银行的客户流失较为严重，流失率可达20%。而获得新客的成本是维护老客户的5倍。因此，从客户交易数据中挖掘出对流失有影响的信息，建立高效的客户流失预警体系尤为重要。
#
# 本次项目的目标主要是如下几点：
#
# - 识别导致客户流失的因素，并进行可视化。
# - 建立一个预测模型，预测分类客户是否流失，并根据模型的性能，选择一个最优模型。
#
# 根据识别出的因素及客户流失的历史数据对现有客户进行流失预测，以使银行的相关部门更容易地应对，针对不同的客群提供不同的维护手段，从而降低客户的流失率。
#
# 数据来源于国外匿名化处理后的真实数据。
# 比赛网址：https://www.kaggle.com/yogirj/churn-modelling

# %% [markdown]
# # 业务理解

# %% [markdown]
# 银行客户流失是指银行的客户终止在该行的所有业务，并销号。但在实际运营中，对于具体业务部门，银行客户流失可以定位为特定的业务终止行为。
#
# 商业银行的客户流失较为严重，流失率可达20%。而获得新客的成本是维护老客户的5倍。因此，从客户交易数据中挖掘出对流失有影响的信息，建立高效的客户流失预警体系尤为重要。
#
# 本次实验的目标主要是如下几点：
#    - 1.识别导致客户流失的因素，并进行可视化。
#    - 2.建立一个预测模型，预测分类客户是否流失，并根据模型的性能，选择一个最优模型。
#
# 根据识别出的因素及客户流失的历史数据对现有客户进行流失预测，以使银行的相关部门更容易地应对，针对不同的客群提供不同的维护手段，从而降低客户的流失率。

# %% [markdown]
# # 数据理解

# %% [markdown]
# ## 导入合适的包

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %% [markdown]
# ## 获取数据

# %%
df = pd.read_csv('Churn_Modelling.csv', delimiter=',')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## 数据描述

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# 数据集中共有14个特征变量，分别为行号（RowNumber）、客户编号（CustomerID）、客户姓氏（Surname）、信用分数（CreditScore）、客户所在地（Geography）、性别（Gender）、年龄（Age）、成为银行客户年数（Tenure）、账户余额（Balance）、
# 客户使用产品数量（NumOfProducts）、是否拥有本行信用卡（HasCrCard）、是否为活跃用户（IsActiveMember）、估计薪资（EstimatedSalary）、是否已流失（Exited）。其中有8个数字变量，5个分类变量，Exited作为目标变量。

# %% [markdown]
# ## 缺失值分析

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# 根据输出结果可知，数据集中不存在缺失值。

# %% [markdown]
# # 数据准备

# %% [markdown]
# ## 特征工程

# %% [markdown]
# 由于前3个特征变量——行号（RowNumber）、客户编号（CustomerId）、客户姓氏（Surname）与实验无关，因此要将它们排除在外。

# %%
df = df.drop(["RowNumber", "CustomerId", "Surname"], axis = 1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# **可视化分析**

# %%
labels = 'Exited', 'Retained'
sizes = [df.Exited[df['Exited']==1].count(), df.Exited[df['Exited']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 5))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.2f%%',
        shadow=True, startangle=16)
ax1.axis('equal')
plt.title("Proportion of customer churned and retained", size = 15)
plt.show()

# %% [markdown]
# 从上图可得，数据集中大约有20%的客户流失了。由于银行识别并保留这一群体很有意义，我们需要确保所选模型的确能非常准确地预测这20％。

# %%
#查看分类变量的关系
fig, axarr = plt.subplots(2, 2, figsize=(20, 12))
sns.countplot(x='Geography', hue = 'Exited',data = df, ax=axarr[0][0])
sns.countplot(x='Gender', hue = 'Exited',data = df, ax=axarr[0][1])
sns.countplot(x='HasCrCard', hue = 'Exited',data = df, ax=axarr[1][0])
sns.countplot(x='IsActiveMember', hue = 'Exited',data = df, ax=axarr[1][1])
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %% [markdown]
# 由图可以发现数据有以下特点：
# - 1.大部分数据来自法国。 但是，流失客户的比例与客户数量成反比，因此银行在客户较少的地区可能存在问题（可能没有分配足够的客户服务资源）。
# - 2.女性顾客流失的比例也高于男性顾客。
# - 3.大多数流失的客户是拥有信用卡的客户。 鉴于大多数客户都拥有信用卡，这可能只是一个巧合。
# - 4.不活跃的客户流失率更大。不活跃的客户总体比例相当高，银行可能需要采取措施，将该群体转变为活跃客户，从而改善客户流失的状况。

# %%
#查看数值变量的关系
fig, axarr = plt.subplots(3, 2, figsize=(20, 12))
sns.boxplot(y='CreditScore',x = 'Exited', hue = 'Exited',data = df, ax=axarr[0][0])
sns.boxplot(y='Age',x = 'Exited', hue = 'Exited',data = df , ax=axarr[0][1])
sns.boxplot(y='Tenure',x = 'Exited', hue = 'Exited',data = df, ax=axarr[1][0])
sns.boxplot(y='Balance',x = 'Exited', hue = 'Exited',data = df, ax=axarr[1][1])
sns.boxplot(y='NumOfProducts',x = 'Exited', hue = 'Exited',data = df, ax=axarr[2][0])
sns.boxplot(y='EstimatedSalary',x = 'Exited', hue = 'Exited',data = df, ax=axarr[2][1])
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='EstimatedSalary'>

# %% [markdown]
# 由图可以发现数据有以下特点：
# - 1.现存客户和流失客户之间的信用评分分布没有显着差异。
# - 2.年龄较大的客户比年龄较小的客户流失更多。不同年龄的人群中存在服务偏好的差异，银行可能需要审查其目标市场或审查不同年龄组之间的保留率的策略。
# - 3.就成为银行客户年数而言，处于极端状态的客户（成为银行客户的年数很大或很小）与处于平均成为银行客户年数的客户相比，更容易流失。
# - 4.银行正在流失拥有大量账户余额的客户，这很可能会耗尽其可用的借贷资金。
# - 5.客户使用产品数量和估计薪资均对于客户流失的概率没有重大影响。

# %%
#将数据集80%的数据作为训练集，20%的数据作为测试集。
df_train = df.sample(frac=0.8,random_state=200)
df_test = df.drop(df_train.index)
print(len(df_train))
print(len(df_test))
# Out:
# 8000
# 2000

# %%
df_train['BalanceSalaryRatio'] = df_train.Balance/df_train.EstimatedSalary
sns.boxplot(y='BalanceSalaryRatio',x = 'Exited', hue = 'Exited',data = df_train)
plt.ylim(-1, 3)
# Out:
# (-1.0, 3.0)

# %% [markdown]
# 从之前的可视化分析可知，估计薪资对客户流失的机会影响很小。 但是，如上图所示，账户余额与估计薪资的比率表明，
# 余额薪资比率较高的客户流失率更高，这需要银行引起重视，因为这会影响其贷款资金的来源。

# %%
df_train['TenureByAge'] = df_train.Tenure/(df_train.Age)
sns.boxplot(y='TenureByAge',x = 'Exited', hue = 'Exited',data = df_train)
plt.ylim(-0.5, 1)
plt.show()

# %% [markdown]
# 由于成为银行客户年数与年龄有一定的关系，因此引入该变量。

# %%
df_train['CreditScoreGivenAge'] = df_train.CreditScore/(df_train.Age)
sns.boxplot(y='CreditScoreGivenAge',x = 'Exited', hue = 'Exited',data = df_train)
plt.ylim(0, 8)
plt.show()

# %% [markdown]
# 最后，考虑到成年人的信用行为，引入此变量来获给定年龄的信用评分。

# %% [markdown]
# ## 数据集成与整理

# %%
continuous_vars = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary', 'BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge']
cat_vars = ['HasCrCard', 'IsActiveMember','Geography', 'Gender']
df_train = df_train[['Exited'] + continuous_vars + cat_vars]
df_train.head()
# Out:
#       Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 8159       0          461   25       6       0.00              2
# 6332       0          619   35       4   90413.12              1
# 8895       0          699   40       8  122038.34              1
# 5351       0          558   41       2  124227.14              1
# 4314       0          638   34       5  133501.36              1
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         15306.29            0.000000     0.240000            18.440000
# 6332         20555.21            4.398550     0.114286            17.685714
# 8895        102085.35            1.195454     0.200000            17.475000
# 5351        111184.67            1.117305     0.048780            13.609756
# 4314        155643.04            0.857741     0.147059            18.764706
#
#       HasCrCard  IsActiveMember Geography  Gender
# 8159          1               1     Spain  Female
# ...

# %% [markdown]
# 对于独热编码来说，我们将0改为-1，这样模型就可以捕捉到一个负关系。

# %%
df_train.loc[df_train.HasCrCard == 0, 'HasCrCard'] = -1
df_train.loc[df_train.IsActiveMember == 0, 'IsActiveMember'] = -1
df_train.head()
# Out:
#       Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 8159       0          461   25       6       0.00              2
# 6332       0          619   35       4   90413.12              1
# 8895       0          699   40       8  122038.34              1
# 5351       0          558   41       2  124227.14              1
# 4314       0          638   34       5  133501.36              1
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         15306.29            0.000000     0.240000            18.440000
# 6332         20555.21            4.398550     0.114286            17.685714
# 8895        102085.35            1.195454     0.200000            17.475000
# 5351        111184.67            1.117305     0.048780            13.609756
# 4314        155643.04            0.857741     0.147059            18.764706
#
#       HasCrCard  IsActiveMember Geography  Gender
# 8159          1               1     Spain  Female
# ...

# %%
lst = ['Geography', 'Gender']
remove = list()
for i in lst:
    if (df_train[i].dtype == np.str or df_train[i].dtype == np.object):
        for j in df_train[i].unique():
            df_train[i+'_'+j] = np.where(df_train[i] == j,1,-1)
        remove.append(i)
df_train = df_train.drop(remove, axis=1)
df_train.head()
# Out:
#       Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 8159       0          461   25       6       0.00              2
# 6332       0          619   35       4   90413.12              1
# 8895       0          699   40       8  122038.34              1
# 5351       0          558   41       2  124227.14              1
# 4314       0          638   34       5  133501.36              1
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         15306.29            0.000000     0.240000            18.440000
# 6332         20555.21            4.398550     0.114286            17.685714
# 8895        102085.35            1.195454     0.200000            17.475000
# 5351        111184.67            1.117305     0.048780            13.609756
# 4314        155643.04            0.857741     0.147059            18.764706
#
#       HasCrCard  IsActiveMember  Geography_Spain  Geography_France  \
# ...

# %%
#缩放连续型数值变量
minVec = df_train[continuous_vars].min().copy()
maxVec = df_train[continuous_vars].max().copy()
df_train[continuous_vars] = (df_train[continuous_vars]-minVec)/(maxVec-minVec)
df_train.head()
# Out:
#       Exited  CreditScore       Age  Tenure   Balance  NumOfProducts  \
# 8159       0        0.222  0.094595     0.6  0.000000       0.333333
# 6332       0        0.538  0.229730     0.4  0.360358       0.000000
# 8895       0        0.698  0.297297     0.8  0.486406       0.000000
# 5351       0        0.416  0.310811     0.2  0.495130       0.000000
# 4314       0        0.576  0.216216     0.5  0.532094       0.000000
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         0.076118            0.000000     0.432000                  NaN
# 6332         0.102376            0.003317     0.205714                  NaN
# 8895         0.510225            0.000901     0.360000                  NaN
# 5351         0.555744            0.000843     0.087805                  NaN
# 4314         0.778145            0.000647     0.264706                  NaN
#
#       HasCrCard  IsActiveMember  Geography_Spain  Geography_France  \
# ...

# %%
df_train.corr()
# Out:
#                        Exited  CreditScore       Age    Tenure   Balance  \
# Exited               1.000000    -0.027732  0.287133 -0.012530  0.117517
# CreditScore         -0.027732     1.000000 -0.013062 -0.007062  0.000268
# Age                  0.287133    -0.013062  1.000000 -0.015823  0.022118
# Tenure              -0.012530    -0.007062 -0.015823  1.000000 -0.017494
# Balance              0.117517     0.000268  0.022118 -0.017494  1.000000
# NumOfProducts       -0.063482     0.004354 -0.032568  0.002679 -0.309866
# EstimatedSalary      0.020153    -0.003831 -0.014186  0.007482  0.016059
# BalanceSalaryRatio   0.024553     0.004710  0.014894  0.023953  0.096607
# TenureByAge         -0.120187    -0.000389 -0.382523  0.889018 -0.030891
# CreditScoreGivenAge       NaN          NaN       NaN       NaN       NaN
# HasCrCard           -0.007200    -0.005631 -0.010311  0.016758 -0.008503
# IsActiveMember      -0.163840     0.028590  0.086148 -0.040482 -0.008045
# ...

# %%
# 测试集数据准备
def DfPrepPipeline(df_predict,df_train_Cols,minVec,maxVec):
   
    df_predict['BalanceSalaryRatio'] = df_predict.Balance/df_predict.EstimatedSalary
    df_predict['TenureByAge'] = df_predict.Tenure/(df_predict.Age - 18)
    df_predict['CreditScoreGivenAge'] = df_predict.CreditScore/(df_predict.Age - 18)
    continuous_vars = ['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary','BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge']
    cat_vars = ['HasCrCard','IsActiveMember',"Geography", "Gender"] 
    df_predict = df_predict[['Exited'] + continuous_vars + cat_vars]
    df_predict.loc[df_predict.HasCrCard == 0, 'HasCrCard'] = -1
    df_predict.loc[df_predict.IsActiveMember == 0, 'IsActiveMember'] = -1
    lst = ["Geography", "Gender"]
    remove = list()
    for i in lst:
        for j in df_predict[i].unique():
            df_predict[i+'_'+j] = np.where(df_predict[i] == j,1,-1)
        remove.append(i)
    df_predict = df_predict.drop(remove, axis=1)
    L = list(set(df_train_Cols) - set(df_predict.columns))
    for l in L:
        df_predict[str(l)] = -1        
    df_predict[continuous_vars] = (df_predict[continuous_vars]-minVec)/(maxVec-minVec)
    df_predict = df_predict[df_train_Cols]
    return df_predict

# %% [markdown]
# # 建模

# %% [markdown]
# ## 搭建环境

# %%
from pycaret.classification import *
exp = setup(data = df_train , target = 'Exited', session_id=123)
# Out:
# <style  type="text/css" >
# </style><table id="T_e19b1340_b065_11eb_a15a_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e19b1340_b065_11eb_a15a_00bb6007a561level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e19b1340_b065_11eb_a15a_00bb6007a561row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e19b1340_b065_11eb_a15a_00bb6007a561row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_e19b1340_b065_11eb_a15a_00bb6007a561level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e19b1340_b065_11eb_a15a_00bb6007a561row1_col0" class="data row1 col0" >Target</td>
# ...

# %% [markdown]
# ## 比较模型

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_056ed7ee_b066_11eb_9398_00bb6007a561 th {
#           text-align: left;
# ...

# %% [markdown]
# ## 创建模型

# %% [markdown]
# **Extreme Gradient Boosting**

# %%
xgboost = create_model('xgboost')
# Out:
# <style  type="text/css" >
# #T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col0,#T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col1,#T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col2,#T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col3,#T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col4,#T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col5,#T_0d69c35c_b066_11eb_b147_00bb6007a561row10_col6{
#             background:  yellow;
#         }</style><table id="T_0d69c35c_b066_11eb_b147_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
print(xgboost)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=123, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='auto',
#               use_label_encoder=True, validate_parameters=1, verbosity=0)

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
gbc = create_model('gbc')
# Out:
# <style  type="text/css" >
# #T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col0,#T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col1,#T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col2,#T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col3,#T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col4,#T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col5,#T_12ead3a4_b066_11eb_9774_00bb6007a561row10_col6{
#             background:  yellow;
#         }</style><table id="T_12ead3a4_b066_11eb_9774_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
print(gbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# **Decision Tree**

# %%
dt = create_model('dt')
# Out:
# <style  type="text/css" >
# #T_138f0874_b066_11eb_abc1_00bb6007a561row10_col0,#T_138f0874_b066_11eb_abc1_00bb6007a561row10_col1,#T_138f0874_b066_11eb_abc1_00bb6007a561row10_col2,#T_138f0874_b066_11eb_abc1_00bb6007a561row10_col3,#T_138f0874_b066_11eb_abc1_00bb6007a561row10_col4,#T_138f0874_b066_11eb_abc1_00bb6007a561row10_col5,#T_138f0874_b066_11eb_abc1_00bb6007a561row10_col6{
#             background:  yellow;
#         }</style><table id="T_138f0874_b066_11eb_abc1_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
print(dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %% [markdown]
# ### 调优模型

# %% [markdown]
# **Extreme Gradient Boosting**

# %%
tuned_xgboost = tune_model(xgboost)
# Out:
# <style  type="text/css" >
# #T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col0,#T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col1,#T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col2,#T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col3,#T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col4,#T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col5,#T_adf70c5e_b066_11eb_bf5c_00bb6007a561row10_col6{
#             background:  yellow;
#         }</style><table id="T_adf70c5e_b066_11eb_bf5c_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
print(tuned_xgboost)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.0005, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=123, reg_alpha=0.05,
#               reg_lambda=5, scale_pos_weight=2.1, subsample=0.5,
#               tree_method='auto', use_label_encoder=True, validate_parameters=1,
#               verbosity=0)

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
tuned_gbc = tune_model(gbc)
# Out:
# <style  type="text/css" >
# #T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col0,#T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col1,#T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col2,#T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col3,#T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col4,#T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col5,#T_c1f6ccf0_b066_11eb_81ac_00bb6007a561row10_col6{
#             background:  yellow;
#         }</style><table id="T_c1f6ccf0_b066_11eb_81ac_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
print(tuned_gbc)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.15, loss='deviance', max_depth=7,
#                            max_features=1.0, max_leaf_nodes=None,
#                            min_impurity_decrease=0.02, min_impurity_split=None,
#                            min_samples_leaf=5, min_samples_split=5,
#                            min_weight_fraction_leaf=0.0, n_estimators=230,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=123, subsample=0.85, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %% [markdown]
# **Decision Tree**

# %%
tuned_dt = tune_model(dt)
# Out:
# <style  type="text/css" >
# #T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col0,#T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col1,#T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col2,#T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col3,#T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col4,#T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col5,#T_c2731e14_b066_11eb_a1c2_00bb6007a561row10_col6{
#             background:  yellow;
#         }</style><table id="T_c2731e14_b066_11eb_a1c2_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
print(tuned_dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=6, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.002, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=123, splitter='best')

# %% [markdown]
# 实验主要目的是预测可能会流失的客户，以便银行可以采取措施来防止流失，因此召回率（Recall）指标得分更为重要。根据以上结果的对比，将Extreme Gradient Boosting作为最优模型。

# %% [markdown]
# # 评价

# %% [markdown]
# ## 评估模型

# %%
plot_model(tuned_xgboost, plot = 'confusion_matrix')

# %%
plot_model(tuned_xgboost, plot = 'class_report')

# %%
plot_model(tuned_xgboost, plot='boundary')

# %%
plot_model(tuned_xgboost, plot='error')

# %%
evaluate_model(tuned_xgboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## 测试模型

# %%
predict_model(tuned_xgboost);
# Out:
# <style  type="text/css" >
# </style><table id="T_ccd9ae6e_b066_11eb_bbd4_00bb6007a561" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ccd9ae6e_b066_11eb_bbd4_00bb6007a561level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ccd9ae6e_b066_11eb_bbd4_00bb6007a561row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
# ...

# %% [markdown]
# ## 部署模型

# %%
final_xgboost = finalize_model(tuned_xgboost)

# %%
print(final_xgboost)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.0005, max_delta_step=0, max_depth=10,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=-1, num_parallel_tree=1,
#               objective='binary:logistic', random_state=123, reg_alpha=0.05,
#               reg_lambda=5, scale_pos_weight=2.1, subsample=0.5,
#               tree_method='auto', use_label_encoder=True, validate_parameters=1,
#               verbosity=0)

# %% [markdown]
# ## 模型预测

# %%
df_test = DfPrepPipeline(df_test,df_train.columns,minVec,maxVec)
df_test = df_test.mask(np.isinf(df_test))
df_test = df_test.dropna()

# %%
unseen_predictions = predict_model(final_xgboost, data=df_test)
unseen_predictions.head()
# Out:
#     Exited  CreditScore       Age  Tenure   Balance  NumOfProducts  \
# 2        1        0.304  0.324324     0.8  0.636357       0.666667
# 3        0        0.698  0.283784     0.1  0.000000       0.333333
# 5        1        0.590  0.351351     0.8  0.453394       0.333333
# 17       0        0.398  0.081081     0.9  0.000000       0.333333
# 18       0        0.474  0.364865     0.6  0.000000       0.000000
#
#     EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 2          0.569485            0.001057     0.600000             0.382081
# 3          0.468912            0.000000     0.085714             0.676360
# 5          0.748699            0.000573     0.553846             0.474654
# 17         0.071617            0.000000     2.700000             2.061367
# 18         0.793361            0.000000     0.400000             0.401687
#
#     HasCrCard  IsActiveMember  Geography_Spain  Geography_France  \
# ...

# %% [markdown]
# ## 保存实验

# %%
save_model(final_xgboost,'Final Xgboost Model 20200719')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Exited',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strat...
#                                 interaction_constraints='', learning_rate=0.0005,
#                                 max_delta_step=0, max_depth=10,
# ...

# %% [markdown]
# # 结论

# %% [markdown]
# - 在识别影响因素方面，由实验可看出，信用分数、客户所在地、性别、年龄、成为银行客户年数、账户余额、客户使用产品数量、是否拥有本行信用卡、是否为活跃用户、估计薪资均对银行客户流失有一定的影响，银行可以根据识别结果对症下药，采取解决措施。
# - 在预测方面，模型对未见的测试集数据的预测结果精度略高，银行可以运用此模型作为参考，帮助其识别流失客户。但是，尽管此模型具有很高的准确性，但仍存在未识别出流失客户的情况，可能是还有其他的特征变量未考虑进来，或者是数据处理还不够恰当、准确，导致模型存在误差。因此，模型仍有改进的空间。
# -目标人群定位
# -1、根据特征重要性排序，特征估计薪资和存贷款情况是影响预测客户流失的较为重要因素。结合之前的特征频数分布图得知，该银行客户各收入层分布均匀，说明银行并没有重视目标收入客户定位，没有明确目标人群，更多客户选择存入较少的钱。目标客户定位有助于银行指定针对性策略，提供适合目标客户的商品和服务，提高银行的竞争力。例如中国工商银行以中等收入阶层为重点目标客户；中国农业银行重点服务“三农”，建立城乡一体化；中国银行更倾向于中高端客户和大型企业。因此，认为该银行有必要明确目标客户群。
# -2、用户关怀策略。客户使用该银行产品年数也是影响模型的重要因素。为了挽留老客户，推出相应的关怀和激励策略十分有必要。对于使用产品年数较长的客户，银行可以采用会员积分制、会员优先服务、老客户感恩回馈等活动，令客户感受到银行对客户的重视；对于银行新用户，可通过各种优惠活动吸引客户使用，如与政府和商家合作推出打折活动，同时也要通过会员积分制激励新用户向老用户的转换。
# -3、高信用评级激励制度。信用得分也是预测客户流失的重要影响因素。信用得分是银行用来评估客户是否具有获得信用卡的资格。因此，为了挽留银行高信用用户，银行可推出一系列信用卡激励策略，一来可以挽留更多高信用用户，二可以刺激其他未办理信用卡的高信用评级用户申请该银行信用卡
